# %%
import os

city = 'alfenas'
path_city_files = os.getcwd() + '\\database\\' + city
path_refined_measures = path_city_files + '\\' + city + '_medidas_refinadas.csv'
path_measures = path_city_files + '\\' + city + '_medidas.csv'
path_graph = path_city_files + '\\' + city + '.graphml'
path_police_data = os.getcwd() + '\\cities-data\\DadosRefinados_' + city + '.csv'

# %%
#visualização inicial utilizando seaborn

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

dadoscalculados = pd.read_csv(path_refined_measures)
janela, graficos = plt.subplots(nrows=2, ncols=3, figsize=(25, 15))
plt.tight_layout()

sns.regplot(data=dadoscalculados, x="closeness_centrality", y="quantidade_ocorrencia", ax=graficos[0][0])
sns.regplot(data=dadoscalculados, x="betweenes_centrality", y="quantidade_ocorrencia", ax=graficos[0][1])
sns.regplot(data=dadoscalculados, x="degree_centrality", y="quantidade_ocorrencia", ax=graficos[0][2])
sns.regplot(data=dadoscalculados, x="eigenvector_centrality", y="quantidade_ocorrencia", ax=graficos[1][0])
sns.regplot(data=dadoscalculados, x="pagerank_centrality", y="quantidade_ocorrencia", ax=graficos[1][1])
sns.regplot(data=dadoscalculados, x="distancia_universidade", y="quantidade_ocorrencia", ax=graficos[1][2])
# Out:
# <Axes: xlabel='distancia_universidade', ylabel='quantidade_ocorrencia'>

# %%
#visualização inicial utilizando seaborn

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

dadoscalculados = pd.read_csv(path_refined_measures)
janela, graficos = plt.subplots(nrows=2, ncols=3, figsize=(25, 15))
plt.tight_layout()

sns.regplot(data=dadoscalculados, x="closeness_centrality", y="quantidade_ocorrencia_2", ax=graficos[0][0])
sns.regplot(data=dadoscalculados, x="betweenes_centrality", y="quantidade_ocorrencia_2", ax=graficos[0][1])
sns.regplot(data=dadoscalculados, x="degree_centrality", y="quantidade_ocorrencia_2", ax=graficos[0][2])
sns.regplot(data=dadoscalculados, x="eigenvector_centrality", y="quantidade_ocorrencia_2", ax=graficos[1][0])
sns.regplot(data=dadoscalculados, x="pagerank_centrality", y="quantidade_ocorrencia_2", ax=graficos[1][1])
sns.regplot(data=dadoscalculados, x="distancia_universidade", y="quantidade_ocorrencia_2", ax=graficos[1][2])
# Out:
# <Axes: xlabel='distancia_universidade', ylabel='quantidade_ocorrencia_2'>

# %%
#visualização inicial utilizando seaborn

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

dadoscalculados = pd.read_csv(path_refined_measures)
janela, graficos = plt.subplots(nrows=2, ncols=3, figsize=(25, 15))
plt.tight_layout()

sns.regplot(data=dadoscalculados, x="closeness_centrality", y="medida_influencia_crime", ax=graficos[0][0])
sns.regplot(data=dadoscalculados, x="betweenes_centrality", y="medida_influencia_crime", ax=graficos[0][1])
sns.regplot(data=dadoscalculados, x="degree_centrality", y="medida_influencia_crime", ax=graficos[0][2])
sns.regplot(data=dadoscalculados, x="eigenvector_centrality", y="medida_influencia_crime", ax=graficos[1][0])
sns.regplot(data=dadoscalculados, x="pagerank_centrality", y="medida_influencia_crime", ax=graficos[1][1])
sns.regplot(data=dadoscalculados, x="distancia_universidade", y="medida_influencia_crime", ax=graficos[1][2])
# Out:
# <Axes: xlabel='distancia_universidade', ylabel='medida_influencia_crime'>

# %%
import pandas as pd

dados = pd.read_csv(path_refined_measures)

print('closeness pearson = ' + str(dados['closeness_centrality'].corr(dados['quantidade_ocorrencia'])))
print('closeness spearman = ' + str(dados['closeness_centrality'].corr(dados['quantidade_ocorrencia'], method="spearman")))
print('closeness kendall = ' + str(dados['closeness_centrality'].corr(dados['quantidade_ocorrencia'], method="kendall")))
print()
print('betweenes pearson = ' + str(dados['betweenes_centrality'].corr(dados['quantidade_ocorrencia'])))
print('betweenes spearman = ' + str(dados['betweenes_centrality'].corr(dados['quantidade_ocorrencia'], method="spearman")))
print('betweenes kendall = ' + str(dados['betweenes_centrality'].corr(dados['quantidade_ocorrencia'], method="kendall")))
print()
print('degree pearson = ' + str(dados['degree_centrality'].corr(dados['quantidade_ocorrencia'])))
print('degree spearman = ' + str(dados['degree_centrality'].corr(dados['quantidade_ocorrencia'], method="spearman")))
print('degree kendall = ' + str(dados['degree_centrality'].corr(dados['quantidade_ocorrencia'], method="kendall")))
print()
print('eigenvector pearson = ' + str(dados['eigenvector_centrality'].corr(dados['quantidade_ocorrencia'])))
print('eigenvector spearman = ' + str(dados['eigenvector_centrality'].corr(dados['quantidade_ocorrencia'], method="spearman")))
print('eigenvector kendall = ' + str(dados['eigenvector_centrality'].corr(dados['quantidade_ocorrencia'], method="kendall")))
print()
print('pagerank pearson = ' + str(dados['pagerank_centrality'].corr(dados['quantidade_ocorrencia'])))
print('pagerank spearman = ' + str(dados['pagerank_centrality'].corr(dados['quantidade_ocorrencia'], method="spearman")))
print('pagerank kendall = ' + str(dados['pagerank_centrality'].corr(dados['quantidade_ocorrencia'], method="kendall")))
print()
print('distancia universidade pearson = ' + str(dados['distancia_universidade'].corr(dados['quantidade_ocorrencia'])))
print('distancia universidade spearman = ' + str(dados['distancia_universidade'].corr(dados['quantidade_ocorrencia'], method="spearman")))
print('distancia universidade kendall = ' + str(dados['distancia_universidade'].corr(dados['quantidade_ocorrencia'], method="kendall")))
# Out:
# closeness pearson = 0.28723127324053044
# closeness spearman = 0.34836813855374804
# closeness kendall = 0.2760833380414151
#
# betweenes pearson = 0.14447159328338713
# betweenes spearman = 0.18108797092848106
# betweenes kendall = 0.1431040682507944
#
# degree pearson = 0.06714564766516455
# degree spearman = 0.14470133492853895
# degree kendall = 0.12683124946861374
#
# eigenvector pearson = 0.1206029787171648
# eigenvector spearman = 0.21089733774545902
# eigenvector kendall = 0.16530408470154667
#
# pagerank pearson = 0.020476034242358214
# pagerank spearman = 0.06158713105700525
# pagerank kendall = 0.04803827252404217
#
# distancia universidade pearson = -0.21726715937155916
# distancia universidade spearman = -0.34458048999363683
# distancia universidade kendall = -0.2726553983871119

# %%
import pandas as pd

dados = pd.read_csv(path_refined_measures)

print('closeness pearson = ' + str(dados['closeness_centrality'].corr(dados['quantidade_ocorrencia_2'])))
print('closeness spearman = ' + str(dados['closeness_centrality'].corr(dados['quantidade_ocorrencia_2'], method="spearman")))
print('closeness kendall = ' + str(dados['closeness_centrality'].corr(dados['quantidade_ocorrencia_2'], method="kendall")))
print()
print('betweenes pearson = ' + str(dados['betweenes_centrality'].corr(dados['quantidade_ocorrencia_2'])))
print('betweenes spearman = ' + str(dados['betweenes_centrality'].corr(dados['quantidade_ocorrencia_2'], method="spearman")))
print('betweenes kendall = ' + str(dados['betweenes_centrality'].corr(dados['quantidade_ocorrencia_2'], method="kendall")))
print()
print('degree pearson = ' + str(dados['degree_centrality'].corr(dados['quantidade_ocorrencia_2'])))
print('degree spearman = ' + str(dados['degree_centrality'].corr(dados['quantidade_ocorrencia_2'], method="spearman")))
print('degree kendall = ' + str(dados['degree_centrality'].corr(dados['quantidade_ocorrencia_2'], method="kendall")))
print()
print('eigenvector pearson = ' + str(dados['eigenvector_centrality'].corr(dados['quantidade_ocorrencia_2'])))
print('eigenvector spearman = ' + str(dados['eigenvector_centrality'].corr(dados['quantidade_ocorrencia_2'], method="spearman")))
print('eigenvector kendall = ' + str(dados['eigenvector_centrality'].corr(dados['quantidade_ocorrencia_2'], method="kendall")))
print()
print('pagerank pearson = ' + str(dados['pagerank_centrality'].corr(dados['quantidade_ocorrencia_2'])))
print('pagerank spearman = ' + str(dados['pagerank_centrality'].corr(dados['quantidade_ocorrencia_2'], method="spearman")))
print('pagerank kendall = ' + str(dados['pagerank_centrality'].corr(dados['quantidade_ocorrencia_2'], method="kendall")))
print()
print('distancia universidade pearson = ' + str(dados['distancia_universidade'].corr(dados['quantidade_ocorrencia_2'])))
print('distancia universidade spearman = ' + str(dados['distancia_universidade'].corr(dados['quantidade_ocorrencia_2'], method="spearman")))
print('distancia universidade kendall = ' + str(dados['distancia_universidade'].corr(dados['quantidade_ocorrencia_2'], method="kendall")))
# Out:
# closeness pearson = 0.41194059424970275
# closeness spearman = 0.48744656088824007
# closeness kendall = 0.363088762366918
#
# betweenes pearson = 0.16405050267910812
# betweenes spearman = 0.2155578567696987
# betweenes kendall = 0.1561314236937755
#
# degree pearson = 0.08785825690929779
# degree spearman = 0.14658335929549546
# degree kendall = 0.1178733542474638
#
# eigenvector pearson = 0.1489252204443018
# eigenvector spearman = 0.30063193965409296
# eigenvector kendall = 0.21570635924716164
#
# pagerank pearson = 0.029161266158873808
# pagerank spearman = 0.04963073537674725
# pagerank kendall = 0.03578854550475605
#
# distancia universidade pearson = -0.321767598978472
# distancia universidade spearman = -0.473676977095723
# distancia universidade kendall = -0.3526465587155186

# %%
import pandas as pd

dados = pd.read_csv(path_refined_measures)

print('closeness pearson = ' + str(dados['closeness_centrality'].corr(dados['medida_influencia_crime'])))
print('closeness spearman = ' + str(dados['closeness_centrality'].corr(dados['medida_influencia_crime'], method="spearman")))
print('closeness kendall = ' + str(dados['closeness_centrality'].corr(dados['medida_influencia_crime'], method="kendall")))
print()
print('betweenes pearson = ' + str(dados['betweenes_centrality'].corr(dados['medida_influencia_crime'])))
print('betweenes spearman = ' + str(dados['betweenes_centrality'].corr(dados['medida_influencia_crime'], method="spearman")))
print('betweenes kendall = ' + str(dados['betweenes_centrality'].corr(dados['medida_influencia_crime'], method="kendall")))
print()
print('degree pearson = ' + str(dados['degree_centrality'].corr(dados['medida_influencia_crime'])))
print('degree spearman = ' + str(dados['degree_centrality'].corr(dados['medida_influencia_crime'], method="spearman")))
print('degree kendall = ' + str(dados['degree_centrality'].corr(dados['medida_influencia_crime'], method="kendall")))
print()
print('eigenvector pearson = ' + str(dados['eigenvector_centrality'].corr(dados['medida_influencia_crime'])))
print('eigenvector spearman = ' + str(dados['eigenvector_centrality'].corr(dados['medida_influencia_crime'], method="spearman")))
print('eigenvector kendall = ' + str(dados['eigenvector_centrality'].corr(dados['medida_influencia_crime'], method="kendall")))
print()
print('pagerank pearson = ' + str(dados['pagerank_centrality'].corr(dados['medida_influencia_crime'])))
print('pagerank spearman = ' + str(dados['pagerank_centrality'].corr(dados['medida_influencia_crime'], method="spearman")))
print('pagerank kendall = ' + str(dados['pagerank_centrality'].corr(dados['medida_influencia_crime'], method="kendall")))
print()
print('distancia universidade pearson = ' + str(dados['distancia_universidade'].corr(dados['medida_influencia_crime'])))
print('distancia universidade spearman = ' + str(dados['distancia_universidade'].corr(dados['medida_influencia_crime'], method="spearman")))
print('distancia universidade kendall = ' + str(dados['distancia_universidade'].corr(dados['medida_influencia_crime'], method="kendall")))
# Out:
# closeness pearson = 0.37986103290384465
# closeness spearman = 0.5279928032286978
# closeness kendall = 0.38551319674529894
#
# betweenes pearson = 0.1269574569120468
# betweenes spearman = 0.2235537610484788
# betweenes kendall = 0.1590324951959763
#
# degree pearson = 0.08757330810312373
# degree spearman = 0.1638241801722474
# degree kendall = 0.12975042590426553
#
# eigenvector pearson = 0.1237516352914699
# eigenvector spearman = 0.34590620366614805
# eigenvector kendall = 0.2432646807894509
#
# pagerank pearson = 0.04191017167636804
# pagerank spearman = 0.049729108678195466
# pagerank kendall = 0.03510721811424652
#
# distancia universidade pearson = -0.347644553342083
# distancia universidade spearman = -0.5330536090450068
# distancia universidade kendall = -0.3887398122913252

# %%
from scipy.stats import shapiro
import pandas as pd

dados = pd.read_csv(path_refined_measures)

print('closeness_centrality = ' + str(shapiro(dados['closeness_centrality'])))
print('betweenes_centrality = ' + str(shapiro(dados['betweenes_centrality'])))
print('degree_centrality = ' + str(shapiro(dados['degree_centrality'])))
print('eigenvector_centrality = ' + str(shapiro(dados['eigenvector_centrality'])))
print('pagerank_centrality = ' + str(shapiro(dados['pagerank_centrality'])))
print('distancia_universidade = ' + str(shapiro(dados['distancia_universidade'])))
print('medida_influencia_crime = ' + str(shapiro(dados['medida_influencia_crime'])))
print('quantidade_ocorrencia = ' + str(shapiro(dados['quantidade_ocorrencia'])))
print('quantidade_ocorrencia_2 = ' + str(shapiro(dados['quantidade_ocorrencia_2'])))
# Out:
# closeness_centrality = ShapiroResult(statistic=0.9706934690475464, pvalue=4.758947298974866e-23)
# betweenes_centrality = ShapiroResult(statistic=0.6270478963851929, pvalue=0.0)
# degree_centrality = ShapiroResult(statistic=0.863436222076416, pvalue=1.8357009882655104e-43)
# eigenvector_centrality = ShapiroResult(statistic=0.16348272562026978, pvalue=0.0)
# pagerank_centrality = ShapiroResult(statistic=0.9747020602226257, pvalue=1.885332629961057e-21)
# distancia_universidade = ShapiroResult(statistic=0.9557902812957764, pvalue=7.670435374767557e-28)
# medida_influencia_crime = ShapiroResult(statistic=0.5090191960334778, pvalue=0.0)
# quantidade_ocorrencia = ShapiroResult(statistic=0.5014901161193848, pvalue=0.0)
# quantidade_ocorrencia_2 = ShapiroResult(statistic=0.6852800250053406, pvalue=0.0)

# %%
from matplotlib import pyplot as plt
import seaborn as sns

janela, graficos = plt.subplots(nrows=2, ncols=3, figsize=(25, 15))
plt.tight_layout()

dados = pd.read_csv(path_refined_measures)
eigenvector = dados['eigenvector_centrality']
eigenvector.describe(include='all').round(6)
#sns.histplot(dados, x="closeness_centrality", ax=graficos[0][0])
#sns.histplot(dados, x="betweenes_centrality", ax=graficos[0][1])
#sns.histplot(dados, x="degree_centrality", ax=graficos[0][2])
#sns.histplot(dados, x="eigenvector_centrality", ax=graficos[1][0])
#sns.histplot(dados, x="pagerank_centrality", ax=graficos[1][1])
#sns.histplot(dados, x="distancia_universidade", ax=graficos[1][2])
# Out:
# count    2693.000000
# mean        0.014639
# std         0.085272
# min         0.000000
# 25%         0.000000
# 50%         0.000004
# 75%         0.000228
# max         1.000000
# Name: eigenvector_centrality, dtype: float64
